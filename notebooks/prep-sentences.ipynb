# %% [markdown]
# # Prep sentences
# Preparing training data for classification by extracting features
#
# **Target (y):**
# - [x] has dataset reference
#
# **Features (X:**
# - [x] has indicator terms
# - [x] in section
# - [x] has acronym

# %%
import glob
import json
import re
import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import sent_tokenize

from random import randint

# %%
path = '../data/'
DATA_DIR = '/nfs/turbo/hrg/coleridge/'

# %%
def clean_text(txt):
    """
    Convert to lowercase, remove special characters, and punctuation.
    """
    return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower())

def find_acronyms(txt):
    """
    finds and returns a sequence of capital letters
    for use on dataset_titles, dataset_labels, or full text
    """
    matches = re.findall(r"\b[A-Z\.]{2,}s?\b", txt)
    if matches:
        return 1
    else:
        return 0

def count_acronyms(txt):
    """
    finds and returns a sequence of capital letters
    for use on dataset_titles, dataset_labels, or full text
    """
    matches = re.findall(r"\b[A-Z\.]{2,}s?\b", txt)
    if matches:
        return len(matches)
    else:
        return 0

# def find_ents(txt):
#     """
#     loads our custom model to determine if a sentence has a dataset reference, binary
#     """
#     doc = custom_ner_model(txt)
#     if len(doc.ents) > 0:
#         return 1
#     else:
#         return 0

# def count_ents(txt):
#     """
#     loads our custom model to determine if a sentence has a dataset reference, counts number of times entities appear
#     """
#     label = []
#     doc = custom_ner_model(txt)
#     if len(doc.ents) > 0:
#         for entity in doc:
#             label.append(doc.ents)
#         return len(label)
#     else:
#         return 0

# %% [markdown]
# ## Data

# %%
submission_df = pd.read_csv('../data/sample_submission.csv')

# %%
df_train = pd.read_csv('../data/train.csv')

# %%
train_files = glob.glob('../data/train/*.json')

df_train_pubs = pd.DataFrame()
for train_file in train_files: 
    file_data = pd.read_json(train_file)
    file_data.insert(0,'Id', train_file.split('/')[-1].split('.')[0])
    df_train_pubs = pd.concat([df_train_pubs, file_data])

df_train_pubs['clean_text'] = df_train_pubs['text'].apply(clean_text)
df_train_pubs.head()
# Out:
#                                      Id  \
# 0  07cbcedc-9f95-42e3-8340-468a866916b9
# 1  07cbcedc-9f95-42e3-8340-468a866916b9
# 2  07cbcedc-9f95-42e3-8340-468a866916b9
# 3  07cbcedc-9f95-42e3-8340-468a866916b9
# 4  07cbcedc-9f95-42e3-8340-468a866916b9
#
#                                        section_title  \
# 0                                           Abstract
# 1
# 2  Socioeconomic Disadvantage and Early Work Expe...
# 3                        The Youth Development Study
# 4  Teenage Work and the Process of Socioeconomic ...
#
#                                                 text  \
# 0  In this study, we highlight the importance of ...
# 1  consequences of these early work experiences a...
# 2  Some scholars have suggested that long work ho...
# 3  To address these issues, we draw on data from ...
# 4  Precursors of Teenage Work. We first distingui...
#
#                                           clean_text
# 0  in this study we highlight the importance of s...
# 1  consequences of these early work experiences a...
# 2  some scholars have suggested that long work ho...
# 3  to address these issues we draw on data from t...
# 4  precursors of teenage work we first distinguis...

# %%
df_full = df_train.merge(df_train_pubs, on='Id')
df_full = df_full.drop(columns=['pub_title','dataset_title','cleaned_label','clean_text'])

train_sentences = []

for row in df_full.itertuples():
    for sent in sent_tokenize(row[4]):
        train_sentences.append((row[1], row[2], row[3], sent))
        
df_train_sent = pd.DataFrame(train_sentences, columns=['Id', 'dataset_label', 'section_title', 'sent'])

df_train_sent['dataset_label'] = df_train_sent['dataset_label'].astype(str)
df_train_sent['sent'] = df_train_sent['sent'].astype(str)
df_train_sent['section_title'] = df_train_sent['section_title'].astype(str)

# %% [markdown]
# ## Target
# - consider adding a separate col for `match_count` if we want to predict continuous (number of times dataset is mentioned) rather than categorical (0, 1)

# %%
df_train_sent['match'] = df_train_sent.apply(lambda x: x.dataset_label in x.sent, axis=1)
# df_train_sent['match_count'] = df_train_sent.apply(lambda x: sum(1 if x.dataset_label in x.sent))
df_train_sent['match'].value_counts()
# Out:
# False    6734263
# True       54804
# Name: match, dtype: int64

# %%
df_train_sent['sent_clean'] = df_train_sent['sent'].apply(clean_text)
df_train_sent['section_clean']= df_train_sent['section_title'].apply(clean_text)

df_train_sent
# Out:
#                                            Id  \
# 0        d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1        d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 2        d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 3        d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 4        d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# ...                                       ...
# 6789062  fd23e7e0-a5d2-4f98-992d-9209c85153bb
# 6789063  fd23e7e0-a5d2-4f98-992d-9209c85153bb
# 6789064  fd23e7e0-a5d2-4f98-992d-9209c85153bb
# 6789065  fd23e7e0-a5d2-4f98-992d-9209c85153bb
# 6789066  fd23e7e0-a5d2-4f98-992d-9209c85153bb
#
#                                            dataset_label  \
# 0                  National Education Longitudinal Study
# 1                  National Education Longitudinal Study
# 2                  National Education Longitudinal Study
# 3                  National Education Longitudinal Study
# 4                  National Education Longitudinal Study
# ...                                                  ...
# 6789062  CAS COVID-19 antiviral candidate compounds data
# 6789063  CAS COVID-19 antiviral candidate compounds data
# 6789064  CAS COVID-19 antiviral candidate compounds data
# 6789065  CAS COVID-19 antiviral candidate compounds data
# 6789066  CAS COVID-19 antiviral candidate compounds data
#
#                      section_title  \
# 0        What is this study about?
# 1        What is this study about?
# 2        What is this study about?
# 3        What is this study about?
# 4        What is this study about?
# ...                            ...
# 6789062    Summary and conclusions
# 6789063    Summary and conclusions
# 6789064    Summary and conclusions
# 6789065    Summary and conclusions
# 6789066    Summary and conclusions
#
#                                                       sent  match  \
# 0        This study used data from the National Educati...   True
# 1        The study also reported whether the impacts of...  False
# 2        In addition, a supplemental analysis reports o...  False
# 3        Dual enrollment programs offer college-level l...  False
# 4        The programs offer college courses and/or the ...  False
# ...                                                    ...    ...
# 6789062  As a consequence of the current COVID-19 pande...  False
# 6789063  As a side effect of analyzing the data, we are...  False
# 6789064  In addition, the workflow has been used to det...  False
# 6789065  The material has been used successfully for te...  False
# 6789066  The workflows, tutorials, and the information ...  False
#
#                                                 sent_clean  \
# 0        this study used data from the national educati...
# 1        the study also reported whether the impacts of...
# 2        in addition a supplemental analysis reports on...
# 3        dual enrollment programs offer college level l...
# 4        the programs offer college courses and or the ...
# ...                                                    ...
# 6789062  as a consequence of the current covid 19 pande...
# 6789063  as a side effect of analyzing the data we are ...
# 6789064  in addition the workflow has been used to dete...
# 6789065  the material has been used successfully for te...
# 6789066  the workflows tutorials and the information ga...
#
#                      section_clean
# 0        what is this study about
# 1        what is this study about
# 2        what is this study about
# 3        what is this study about
# 4        what is this study about
# ...                            ...
# 6789062    summary and conclusions
# 6789063    summary and conclusions
# 6789064    summary and conclusions
# 6789065    summary and conclusions
# 6789066    summary and conclusions
#
# [6789067 rows x 7 columns]

# %% [markdown]
# ## Features

# %% [markdown]
# ### has Indicator terms

# %%
df_train_sent['freqData'] = df_train_sent['sent_clean'].str.count('data')
df_train_sent['freqEdu'] = df_train_sent['sent_clean'].str.count('edu')
df_train_sent['freqSample'] = df_train_sent['sent_clean'].str.count('sample')
df_train_sent['freqNational'] = df_train_sent['sent_clean'].str.count('national')
df_train_sent['freqSurvey'] = df_train_sent['sent_clean'].str.count('survey')
df_train_sent['freqPublic'] = df_train_sent['sent_clean'].str.count('public')
df_train_sent['freqAvail'] = df_train_sent['sent_clean'].str.count('avail')
df_train_sent['freqNSF'] = df_train_sent['sent_clean'].str.count('nsf')
df_train_sent['freqGov'] = df_train_sent['sent_clean'].str.count('gov')
df_train_sent['freqAccess'] = df_train_sent['sent_clean'].str.count('access')

df_train_sent.sample(n=10)
# Out:
#                                            Id  \
# 3146495  b262c60b-5b5f-4765-93bd-fb88458b4d7f
# 1145560  773a390a-8b92-40a6-931d-c78d76d8f980
# 1761877  ce6ef969-f018-4360-a709-6c6e093ee2f4
# 461686   9ad8bb80-6760-4e93-8583-71adf24ff721
# 2070288  25692b4d-0218-4e86-a5d3-e5ff725e4e67
# 3791492  de3e7ef1-5cf8-4e50-882a-1493e3c5ff3d
# 5382926  bc66d792-89b7-4fb5-9822-b1747ae031e9
# 4616493  170113f9-399c-489e-ab53-2faf5c64c5bc
# 1073629  56634038-aabf-430f-bbd7-7b6cd1cd8d85
# 4435765  430aa11c-0283-411b-8edc-08f5df3db258
#
#                                              dataset_label  \
# 3146495                    Beginning Postsecondary Student
# 1145560  Alzheimer's Disease Neuroimaging Initiative (A...
# 1761877                                               ADNI
# 461686                                     NOAA Tide Gauge
# 2070288                                               ADNI
# 3791492                       Education Longitudinal Study
# 5382926                       Education Longitudinal Study
# 4616493  Survey of Science and Engineering Research Fac...
# 1073629  Alzheimer's Disease Neuroimaging Initiative (A...
# 4435765  Survey of Graduate Students and Postdoctorates...
#
#                           section_title  \
# 3146495        Commissioner's Statement
# 1145560                      Discussion
# 1761877                      Background
# 461686         Tidal Zone Determination
# 2070288                    Introduction
# 3791492                 Domain Coverage
# 5382926  Antecedents to Underemployment
# 4616493
# 1073629      Approach to case selection
# 4435765
#
#                                                       sent  match  \
# 3146495  As various groups voice their desires and conc...  False
# 1145560  Because much literature still benchmarks AD co...  False
# 1761877  Therefore, it would be reasonable to determine...  False
# 461686   Subtidal areas were pixels with a probability ...  False
# 2070288  Autoantibodies against a variety of molecules ...  False
# 3791492  An attempt was made to vary the content, conte...  False
# 5382926  Low income (or working poor) includes full-tim...  False
# 4616493                   National Research Council (NRC).  False
# 1073629  No covariate adjustments are applied to the ra...  False
# 4435765  Part-time employment excludes those employed p...  False
#
#                                                 sent_clean  \
# 3146495  as various groups voice their desires and conc...
# 1145560  because much literature still benchmarks ad co...
# 1761877  therefore it would be reasonable to determine ...
# 461686   subtidal areas were pixels with a probability ...
# 2070288  autoantibodies against a variety of molecules ...
# 3791492  an attempt was made to vary the content contex...
# 5382926  low income or working poor includes full time ...
# 4616493                     national research council nrc
# 1073629  no covariate adjustments are applied to the ra...
# 4435765  part time employment excludes those employed p...
#
#                           section_clean  freqData  freqEdu  freqSample  \
# 3146495        commissioner s statement         0        0           0
# 1145560                      discussion         0        0           0
# 1761877                      background         0        0           0
# 461686         tidal zone determination         0        0           0
# 2070288                    introduction         0        0           0
# 3791492                 domain coverage         0        0           0
# 5382926  antecedents to underemployment         0        0           0
# 4616493                                         0        0           0
# 1073629      approach to case selection         1        0           0
# 4435765                                         0        0           0
#
#          freqNational  freqSurvey  freqPublic  freqAvail  freqNSF  freqGov  \
# 3146495             0           0           0          0        0        0
# 1145560             0           0           0          0        0        0
# 1761877             0           0           0          0        0        0
# 461686              0           0           0          0        0        0
# 2070288             0           0           0          0        0        0
# 3791492             0           0           0          0        0        0
# 5382926             0           0           0          0        0        0
# 4616493             1           0           0          0        0        0
# 1073629             0           0           0          0        0        0
# 4435765             0           0           0          0        0        0
#
#          freqAccess
# 3146495           0
# 1145560           0
# 1761877           0
# 461686            0
# 2070288           0
# 3791492           0
# 5382926           0
# 4616493           0
# 1073629           0
# 4435765           0

# %%
df_train_sent['hasData'] = np.where(df_train_sent['sent_clean'].str.contains('data'), 1, 0)
df_train_sent['hasEdu'] = np.where(df_train_sent['sent_clean'].str.contains('edu'), 1, 0)
df_train_sent['hasSample'] = np.where(df_train_sent['sent_clean'].str.contains('sample'), 1, 0)
df_train_sent['hasNational'] = np.where(df_train_sent['sent_clean'].str.contains('national'), 1, 0)
df_train_sent['hasSurvey'] = np.where(df_train_sent['sent_clean'].str.contains('survey'), 1, 0)
df_train_sent['hasPublic'] = np.where(df_train_sent['sent_clean'].str.contains('public'), 1, 0)
df_train_sent['hasAvail'] = np.where(df_train_sent['sent_clean'].str.contains('survey'), 1, 0)
df_train_sent['hasNSF'] = np.where(df_train_sent['sent_clean'].str.contains('nsf'), 1, 0)
df_train_sent['hasGov'] = np.where(df_train_sent['sent_clean'].str.contains('gov'), 1, 0)
df_train_sent['hasAccess'] = np.where(df_train_sent['sent_clean'].str.contains('access'), 1, 0)

# %% [markdown]
# ### in Section

# %%
df_train_sent['inIntro'] = np.where(df_train_sent['section_clean'].str.contains('intro'), 1, 0)
df_train_sent['inDisc'] = np.where(df_train_sent['section_clean'].str.contains('discus'), 1, 0)
df_train_sent['inAbst'] = np.where(df_train_sent['section_clean'].str.contains('abstr'), 1, 0)
df_train_sent['inResult'] = np.where(df_train_sent['section_clean'].str.contains('resul'), 1, 0)
df_train_sent['inConcl'] = np.where(df_train_sent['section_clean'].str.contains('conclu'), 1, 0)
df_train_sent['inMethod'] = np.where(df_train_sent['section_clean'].str.contains('meth'), 1, 0)
df_train_sent['inBack'] = np.where(df_train_sent['section_clean'].str.contains('back'), 1, 0)
df_train_sent['inData'] = np.where(df_train_sent['section_clean'].str.contains('data'), 1, 0)
df_train_sent['inSumm'] = np.where(df_train_sent['section_clean'].str.contains('summ'), 1, 0)
df_train_sent['inAckno'] = np.where(df_train_sent['section_clean'].str.contains('acknowl'), 1, 0)

df_train_sent.sample(n=10)
# Out:
#                                            Id  \
# 6232258  ad9e5140-f5d5-4711-a917-f526321b6425
# 1809065  c543b483-1bd0-44b2-843f-b9da9adcce8b
# 431033   36858562-8e80-4ce8-816b-7b5daca034d9
# 475354   c4f3fe76-aac2-4c6d-9a09-3f762bf16fea
# 4353648  dd6df078-2010-42fa-ad30-9c302d2ba55b
# 5018868  34f25eee-4aaf-4e67-873d-f34fd1fc5d8d
# 263620   f59da1b0-bb75-41ea-8492-6b1ebca2548d
# 5187305  1a550b18-5a4e-4904-a3c2-f978a1044fa4
# 6131058  086282a3-6a47-4b06-b7b7-c093b9a14236
# 2001141  b0d90754-8b81-4c8f-b8c7-38d534ef6e53
#
#                                        dataset_label  \
# 6232258                        Census of Agriculture
# 1809065                                         ADNI
# 431033         Baltimore Longitudinal Study of Aging
# 475354                               NOAA Tide Gauge
# 4353648                 Education Longitudinal Study
# 5018868  Baccalaureate and Beyond Longitudinal Study
# 263620    Alzheimers Disease Neuroimaging Initiative
# 5187305               Survey of Doctorate Recipients
# 6131058                         World Ocean Database
# 2001141                                         ADNI
#
#                                              section_title  \
# 6232258           Estimation of the Tillage Adoption Model
# 1809065              Progression to AD and non-AD dementia
# 431033   Adiposity, Lipid Abnormalities, and Glucose Me...
# 475354   b. Storm surge and inundation modeling and tid...
# 4353648            National Study of Postsecondary Faculty
# 5018868                 Chapter 1. Why the Pay Gap Matters
# 263620       Evolution model estimation in the atlas space
# 5187305  Section II: The Increasing Presence of the For...
# 6131058
# 2001141                                         DISCUSSION
#
#                                                       sent  match  \
# 6232258  Regarding the first factor, one would expect a...  False
# 1809065  Within the non-AD dementia cohort, 30 (16% of ...  False
# 431033   It appears that testosterone levels are involv...  False
# 475354   At the same time, the mesh covers a large geog...  False
# 4353648  The second cycle of NSOPF (NSOPF:93) was condu...  False
# 5018868  As described in Chapters 3 and 4, mothers pay ...  False
# 263620   The role of the kernel function K h (·) here i...  False
# 5187305  This is seen in Figure 2, which demonstrates h...  False
# 6131058  White, 2017: Climatic regulation of the neurot...  False
# 2001141  It is also the first use of the abbreviated no...  False
#
#                                                 sent_clean  \
# 6232258  regarding the first factor one would expect a ...
# 1809065  within the non ad dementia cohort 30 16 of all...
# 431033   it appears that testosterone levels are involv...
# 475354   at the same time the mesh covers a large geogr...
# 4353648  the second cycle of nsopf nsopf 93 was conduct...
# 5018868  as described in chapters 3 and 4 mothers pay a...
# 263620   the role of the kernel function k h here is to...
# 5187305  this is seen in figure 2 which demonstrates ho...
# 6131058  white 2017 climatic regulation of the neurotox...
# 2001141  it is also the first use of the abbreviated no...
#
#                                              section_clean  freqData  freqEdu  \
# 6232258           estimation of the tillage adoption model         0        0
# 1809065              progression to ad and non ad dementia         0        0
# 431033   adiposity lipid abnormalities and glucose meta...         0        0
# 475354   b storm surge and inundation modeling and tida...         0        0
# 4353648            national study of postsecondary faculty         0        0
# 5018868                  chapter 1 why the pay gap matters         0        1
# 263620       evolution model estimation in the atlas space         0        0
# 5187305  section ii the increasing presence of the fore...         0        0
# 6131058                                                            0        0
# 2001141                                         discussion         0        0
#
#          freqSample  ...  inIntro  inDisc  inAbst  inResult  inConcl  \
# 6232258           0  ...        0       0       0         0        0
# 1809065           0  ...        0       0       0         0        0
# 431033            0  ...        0       0       0         0        0
# 475354            0  ...        0       0       0         0        0
# 4353648           0  ...        0       0       0         0        0
# 5018868           0  ...        0       0       0         0        0
# 263620            0  ...        0       0       0         0        0
# 5187305           0  ...        0       0       0         0        0
# 6131058           0  ...        0       0       0         0        0
# 2001141           0  ...        0       1       0         0        0
#
#          inMethod  inBack  inData  inSumm  inAckno
# 6232258         0       0       0       0        0
# 1809065         0       0       0       0        0
# 431033          0       0       0       0        0
# 475354          0       0       0       0        0
# 4353648         0       0       0       0        0
# 5018868         0       0       0       0        0
# 263620          0       0       0       0        0
# 5187305         0       0       0       0        0
# 6131058         0       0       0       0        0
# 2001141         0       0       0       0        0
#
# [10 rows x 37 columns]

# %% [markdown]
# Check that the columns were added

# %%
df_train_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6789067 entries, 0 to 6789066
# Data columns (total 37 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Id             object
#  1   dataset_label  object
#  2   section_title  object
#  3   sent           object
#  4   match          bool
#  5   sent_clean     object
#  6   section_clean  object
#  7   freqData       int64
#  8   freqEdu        int64
#  9   freqSample     int64
#  10  freqNational   int64
#  11  freqSurvey     int64
#  12  freqPublic     int64
#  13  freqAvail      int64
#  14  freqNSF        int64
#  15  freqGov        int64
#  16  freqAccess     int64
#  17  hasData        int64
#  18  hasEdu         int64
#  19  hasSample      int64
#  20  hasNational    int64
#  21  hasSurvey      int64
#  22  hasPublic      int64
#  23  hasAvail       int64
#  24  hasNSF         int64
#  25  hasGov         int64
#  26  hasAccess      int64
#  27  inIntro        int64
#  28  inDisc         int64
#  29  inAbst         int64
#  30  inResult       int64
#  31  inConcl        int64
#  32  inMethod       int64
#  33  inBack         int64
#  34  inData         int64
#  35  inSumm         int64
#  36  inAckno        int64
# dtypes: bool(1), int64(30), object(6)
# memory usage: 1.8+ GB

# %% [markdown]
# Let's inspect the distribution of the binary "in Introduction"

# %%
df_train_sent['inIntro'].value_counts()
# Out:
# 0    6428172
# 1     360895
# Name: inIntro, dtype: int64

# %% [markdown]
# ### has Acronyms

# %% [markdown]
# This is reported as a binary and a count

# %%
df_train_sent['hasAcronym'] = df_train_sent['sent'].apply(find_acronyms)
df_train_sent['hasAcronym'].value_counts()
# Out:
# 0    4503779
# 1    2285288
# Name: hasAcronym, dtype: int64

# %%
df_train_sent['freqAcronym'] = df_train_sent['sent'].apply(count_acronyms)
df_train_sent['freqAcronym'].unique()
# Out:
# array([    1,     0,     2,     3,     6,     4,     5,     8,    12,
#           11,     7,    10,    15,     9,    17,    19,    16,    14,
#           20,    13,    31,    25,    93,   145,    90,    29,    34,
#           18,    43,    30,    28,    26,    21,    24,    35,    55,
#           22,    23,    44,    33,    41,    42,    57,    75,    27,
#           32,    62,    40,    36,    64,    48,    50,    68,    38,
#           49,  2081,  6231,   403,    51,    74,    39,    47,   320,
#         3157,   178,   281,  3461,   196,    76,   125,   221,    97,
#           56,    52,   117,    86,    98,    70,    53,   154,   743,
#           45,    37,    94,    46,    58,   126,    67,    72,    78,
#          242,   113,   119,   157,    63,   269,    77,    59,   169,
#           61,    54,   387,    73,   120,   162,   186,    65,   133,
#           83,    87,    82,    89,    88,    69,   435,   188,    80,
#          106,   298,   316,   104,   137,   109,   519,   201,   328,
#           66,   123,   202,   180,   371,   108,   488,   116,   449,
#          235,   122,    95,    84,    79,    96,    71,   313,   121,
#          334,   134,   190,   112,   605,   529,   164,   174,   173,
#          172,    91,   118,    85,   181,   151,   312,   440,   132,
#           81,   311,   105,    60,    92,   189,   111,   102,   138,
#          127,   115,   100,   135,   214,   139,   103,   177,  3313,
#          750,  3004,   390, 21276,  6471,   760,  4756,   148,   424,
#          155,   205,   158,   654,  3649,   291,  7340,  2699,   592,
#         1296,   929,   220,  1125,   541, 19603,   497,  1320,   276,
#          227,   245,   239,   434,   380, 22068,  9332,  1858,   893,
#         4809,  3016,  5916,  1218,  7613,   711,  8462,   410,    99,
#          406,  1979,  8782,  1045,  3394,  4240,   165,   990,  4697,
#          473,   581,   525,  4349,  2225,  1900,  1473,  2427,   247,
#         8538,  3417,   222,   444,   282,   322,   252,   549,  7543,
#          422,   187,   131,   149,   107])

# %% [markdown]
# Workaround: Save df as an intermediate frame in case connection is disrupted

# %%
# df_train_sent.to_csv(DATA_DIR + 'train_sents_comb.csv')

# %% [markdown]
# ## Titles
# Check if a sentence has a dataset title from Data.gov or ICPSR
# - consider replacing these files with study names and harvested titles

# %%
icpsr = pd.read_csv(DATA_DIR + 'labels/icpsr_studies.csv')
icpsr_labels = icpsr['NAME'].apply(clean_text).str.replace('\d+', '')

# %%
datagov = pd.read_csv(DATA_DIR + 'labels/kaggle_data_800.csv')
datagov_labels = datagov['title'].apply(clean_text).str.replace('\d+', '')

# %% [markdown]
# Workaround: load intermediate frame for final steps

# %%
# df_train_sent = pd.read_csv(DATA_DIR + 'train_sents_comb.csv', index_col=0)
# df_train_sent.info()
# Out:
# /sw/arcts/centos7/python3.8-anaconda/2020.07/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /sw/arcts/centos7/python3.8-anaconda/2020.07/lib/python3.8/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6789067 entries, 0 to 6789066
# Data columns (total 39 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Id             object
#  1   dataset_label  object
#  2   section_title  object
#  3   sent           object
#  4   match          bool
#  5   sent_clean     object
#  6   section_clean  object
#  7   freqData       int64
#  8   freqEdu        int64
#  9   freqSample     int64
#  10  freqNational   int64
#  11  freqSurvey     int64
#  12  freqPublic     int64
#  13  freqAvail      int64
#  14  freqNSF        int64
#  15  freqGov        int64
#  16  freqAccess     int64
#  17  hasData        int64
#  18  hasEdu         int64
#  19  hasSample      int64
#  20  hasNational    int64
#  21  hasSurvey      int64
#  22  hasPublic      int64
#  23  hasAvail       int64
#  24  hasNSF         int64
#  25  hasGov         int64
#  26  hasAccess      int64
#  27  inIntro        int64
#  28  inDisc         int64
#  29  inAbst         int64
#  30  inResult       int64
#  31  inConcl        int64
#  32  inMethod       int64
#  33  inBack         int64
#  34  inData         int64
#  35  inSumm         int64
#  36  inAckno        int64
#  37  hasAcronym     int64
#  38  freqAcronym    int64
# dtypes: bool(1), int64(32), object(6)
# memory usage: 2.0+ GB

# %%
# %time df_train_sent['hasICPSRTitle'] = df_train_sent['sent_clean'].apply(lambda x: any([k in x for k in icpsr_labels]))
# %time df_train_sent['hasDATAGOVTitle'] = df_train_sent['sent_clean'].apply(lambda x: any([k in x for k in datagov_labels]))

# %%
# df_train_sent.to_csv(DATA_DIR + 'train_sents_all.csv')

# %%
df_train_sent['hasDATAGOVTitle'].value_counts()
# Out:
# False    6663091
# True      125976
# Name: hasDATAGOVTitle, dtype: int64

# %%
df_train_sent['hasICPSRTitle'].value_counts()
# Out:
# False    6770850
# True       18217
# Name: hasICPSRTitle, dtype: int64

# %% [markdown]
# ## Save

# %% [markdown]
# Check that all columns have been added

# %%
# df_train_sent = pd.read_csv(DATA_DIR + 'train_sents_all.csv', index_col=0)
# df_train_sent.info()
# Out:
# /sw/arcts/centos7/python3.8-anaconda/2020.07/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /sw/arcts/centos7/python3.8-anaconda/2020.07/lib/python3.8/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6789067 entries, 0 to 6789066
# Data columns (total 41 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Id               object
#  1   dataset_label    object
#  2   section_title    object
#  3   sent             object
#  4   match            bool
#  5   sent_clean       object
#  6   section_clean    object
#  7   freqData         int64
#  8   freqEdu          int64
#  9   freqSample       int64
#  10  freqNational     int64
#  11  freqSurvey       int64
#  12  freqPublic       int64
#  13  freqAvail        int64
#  14  freqNSF          int64
#  15  freqGov          int64
#  16  freqAccess       int64
#  17  hasData          int64
#  18  hasEdu           int64
#  19  hasSample        int64
#  20  hasNational      int64
#  21  hasSurvey        int64
#  22  hasPublic        int64
#  23  hasAvail         int64
#  24  hasNSF           int64
#  25  hasGov           int64
#  26  hasAccess        int64
#  27  inIntro          int64
#  28  inDisc           int64
#  29  inAbst           int64
#  30  inResult         int64
#  31  inConcl          int64
#  32  inMethod         int64
#  33  inBack           int64
#  34  inData           int64
#  35  inSumm           int64
#  36  inAckno          int64
#  37  hasAcronym       int64
#  38  freqAcronym      int64
#  39  hasICPSRTitle    bool
#  40  hasDATAGOVTitle  bool
# dtypes: bool(3), int64(32), object(6)
# memory usage: 2.0+ GB

# %% [markdown]
# Dataframe with all target and feature columns generated in this notebook

# %%
df_train_sent.to_csv(DATA_DIR + 'train_sents_all.csv')

# %% [markdown]
# ## Filter

# %% [markdown]
# Optional: filter dataframe to keep only true citances

# %%
# df_true = df_train_sent[df_train_sent['match']==True]
# df_true = df_true.drop(columns=['match'])
# df_true['sent'] = df_true['sent'].astype(str)

# df_true

# %% [markdown]
# ## Demo
# Randomly generated example of a citance (a sentence with a data label)
#
# - `section_title`
# - `dataset_label`
# - `sent`

# %%
# example = randint(0, len(df_true))

# print(df_true.iloc[example,2])
# print(df_true.iloc[example,1])
# print(df_true.iloc[example,3])
